# %%
import numpy as np
import tensorflow_datasets as tfds
import tensorflow as tf  # For tf.data
import matplotlib.pyplot as plt
import keras
from keras import layers
from keras.applications import EfficientNetB0
import re
import glob
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pandas as pd
# Out:
# 2025-05-14 11:30:15.417998: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747222215.669659      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747222215.736523      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
imgs = glob.glob(r'/kaggle/input/mushrooms-classification-common-genuss-images/Mushrooms/*/*')
labels = [el.split('/')[5] for el in imgs ]
SIZE = 224

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
X_train, X_test, y_train, y_test = train_test_split(imgs, labels, test_size=0.3, random_state=1, stratify=labels)
train = pd.DataFrame(list(zip(X_train,y_train)), columns =['X','y'])
test = pd.DataFrame(list(zip(X_test,y_test)), columns =['X','y'])

datagen = ImageDataGenerator(
        rescale=1./255)
valid_gen = ImageDataGenerator(rescale=1./255)



train_gen = datagen.flow_from_dataframe(train, x_col='X', y_col="y", target_size=(SIZE, SIZE), interpolation='lanczos',)
test_gen = valid_gen.flow_from_dataframe(test, x_col='X', y_col="y", target_size=(SIZE, SIZE), interpolation='lanczos', )
# Out:
# Found 4699 validated image filenames belonging to 9 classes.
# Found 2015 validated image filenames belonging to 9 classes.

# %%
from tensorflow.keras.datasets import cifar100

# Load the CIFAR-100 dataset
(x_train, y_train), (x_test, y_test) = cifar100.load_data(label_mode='fine')

# Print dataset dimensions
print("Training Images Shape:", x_train.shape)
print("Training Labels Shape:", y_train.shape)
print("Test Images Shape:", x_test.shape)
print("Test Labels Shape:", y_test.shape)
# Out:
# Training Images Shape: (50000, 32, 32, 3)
# Training Labels Shape: (50000, 1)
# Test Images Shape: (10000, 32, 32, 3)
# Test Labels Shape: (10000, 1)

# %%
efb0 = EfficientNetB0()
len(efb0.layers)
# Out:
# 241

# %%
efb0.layers[0]
# Out:
# <InputLayer name=input_layer, built=True>

# %%
pre_trained_model = MobileNetV2(input_shape = (256, 256, 3), 
                            include_top = False, 
                            weights = "imagenet" )
last_layer = pre_trained_model.get_layer('block_15_project_BN')#the name of the last layer you want from the model)
last_output = last_layer.output
input_l = pre_trained_model.input
base_model1 = tf.keras.Model(input_l, last_output
                         )

# %%
for n in the_first_layers:
    last_layer = pre_trained_model.get_layer(n)#the name of the last layer you want from the model)
    last_output = last_layer.output
    input_l = efb0.input
    base_model1 = tf.keras.Model(input_l, last_output)

# %% [markdown]
# # list of layres

# %%
the_first_layers = []
for i, l in enumerate(efb0.layers):
    the_first_layers.append(l.name)
    if i==7:
        break


for i, l in enumerate(efb0.layers):
    if re.match('^block1|^block2',l.name) != None:
        the_first_layers.append(l.name)
    
the_first_layers
# Out:
# ['input_layer_1',
#  'rescaling_2',
#  'normalization_1',
#  'rescaling_3',
#  'stem_conv_pad',
#  'stem_conv',
#  'stem_bn',
#  'stem_activation',
#  'block1a_dwconv',
#  'block1a_bn',
#  'block1a_activation',
#  'block1a_se_squeeze',
#  'block1a_se_reshape',
#  'block1a_se_reduce',
#  'block1a_se_expand',
#  'block1a_se_excite',
#  'block1a_project_conv',
#  'block1a_project_bn',
#  'block2a_expand_conv',
#  'block2a_expand_bn',
#  'block2a_expand_activation',
#  'block2a_dwconv_pad',
#  'block2a_dwconv',
#  'block2a_bn',
#  'block2a_activation',
#  'block2a_se_squeeze',
#  'block2a_se_reshape',
#  'block2a_se_reduce',
#  'block2a_se_expand',
#  'block2a_se_excite',
#  'block2a_project_conv',
#  'block2a_project_bn',
#  'block2b_expand_conv',
#  'block2b_expand_bn',
#  'block2b_expand_activation',
#  'block2b_dwconv',
#  'block2b_bn',
#  'block2b_activation',
#  'block2b_se_squeeze',
#  'block2b_se_reshape',
#  'block2b_se_reduce',
#  'block2b_se_expand',
#  'block2b_se_excite',
# ...

# %% [markdown]
# ### TRy with MODEL same shit

# %%
m1 = tf.keras.Model()

# %%
m1  = keras.Sequential(
     [keras.Input(shape=(224, 224, 3))],
)

for n in the_first_layers[1:11]:
    m1.add(efb0.get_layer(n))

# %%
m1  = keras.Sequential()
#m1.add(keras.Input(shape=(224,224, 3)))

#m1.add()
for i, l in enumerate(efb0.layers):
    m1.add(efb0.layers[i])
    if i==7:
        break



for i, l in enumerate(efb0.layers):
    if re.match('^block1|^block2',l.name) != None:
        m1.add(efb0.layers[i])

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()(m1.output())
prediction_layer = tf.keras.layers.Dense(9)(global_average_layer)
m1 = keras.Model(global_average_layer, prediction_layer, name="EfficientNet")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_31/2365866143.py in <cell line: 0>()
# ----> 1 global_average_layer = tf.keras.layers.GlobalAveragePooling2D()(m1.output())
#       2 prediction_layer = tf.keras.layers.Dense(9)(global_average_layer)
#       3 m1 = keras.Model(global_average_layer, prediction_layer, name="EfficientNet")
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/operation.py in output(self)
#     264             Output tensor or list of output tensors.
#     265         """
# --> 266         return self._get_node_attribute_at_index(0, "output_tensors", "output")
#     267
#     268     def _get_node_attribute_at_index(self, node_index, attr, attr_name):
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/operation.py in _get_node_attribute_at_index(self, node_index, attr, attr_name)
#     283         """
# ...

# %%
inputs = tf.keras.layers.Input(shape=(224,224, 3))
outputs = 
m1 = tf.keras.Model()

# %%
def build_model(model, num_classes=9, shape=(224,224,3)):
    inputs = tf.keras.layers.Input(shape=shape)
    
    model.trainable = True

    # Rebuild top
    x = tf.keras.layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = tf.keras.layers.BatchNormalization()(x)
    
    x = tf.keras.layers.Dropout(0.5, name="top_dropout")(x)
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax", name="pred")(x)

    # Compile
    model = keras.Model(inputs, outputs, name="EfficientNetB1")
    
    return model

# %%
m1= build_model(m1, num_classes=9, shape=(224,224,3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_31/3923370640.py in <cell line: 0>()
# ----> 1 m1= build_model(m1, num_classes=9, shape=(224,224,3))
#
# /tmp/ipykernel_31/815696006.py in build_model(model, num_classes, shape)
#       5
#       6     # Rebuild top
# ----> 7     x = tf.keras.layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
#       8     x = tf.keras.layers.BatchNormalization()(x)
#       9
#
# /usr/local/lib/python3.11/dist-packages/keras/src/ops/operation.py in output(self)
#     264             Output tensor or list of output tensors.
#     265         """
# --> 266         return self._get_node_attribute_at_index(0, "output_tensors", "output")
#     267
#     268     def _get_node_attribute_at_index(self, node_index, attr, attr_name):
#
# ...

# %%
m1.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])



history = m1.fit(
    train_gen,
    epochs=15,
    batch_size=64
)
# Out:
# Epoch 1/15
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_31/318604939.py in <cell line: 0>()
#       5
#       6
# ----> 7 history = m1.fit(
#       8     train_gen,
#       9     epochs=15,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py in sparse_categorical_crossentropy(target, output, from_logits, axis)
#     650         )
#     651     if len(target.shape) != len(output.shape[:-1]):
# --> 652         raise ValueError(
# ...

# %%
m1.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_2 (Rescaling)              │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ normalization_1 (Normalization)      │ (None, 224, 224, 3)         │               7 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_3 (Rescaling)              │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ stem_conv_pad (ZeroPadding2D)        │ (None, 225, 225, 3)         │               0 │
# ...

# %%
def build_model(num_classes=9, shape=(SIZE,SIZE,3)):
    inputs = tf.keras.layers.Input(shape=shape)
    model = EfficientNetB0(include_top=False,
        weights='imagenet',
        input_tensor=inputs, # !
        input_shape=None,
        pooling=None,
        #classes=num_classes,
        classifier_activation='softmax')
    
    model.trainable = True

    # Rebuild top
    x = tf.keras.layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = tf.keras.layers.BatchNormalization()(x)
    
    x = tf.keras.layers.Dropout(0.5, name="top_dropout")(x)
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax", name="pred")(x)

    # Compile
    model = keras.Model(inputs, outputs, name="EfficientNetB1")
    
    return model

# %%
efb0 = EfficientNetB0()

global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
prediction_layer = tf.keras.layers.Dense(9)
efb0.add(global_average_layer)
efb0.add(prediction_layer)


efb0.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = efb0.fit(
    train_gen,
    epochs=15,
    batch_size=64
)
# Out:
# Epoch 1/15
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_31/3918406197.py in <cell line: 0>()
#       7
#       8
# ----> 9 history = efb0.fit(
#      10     train_gen,
#      11     epochs=15,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py in sparse_categorical_crossentropy(target, output, from_logits, axis)
#     650         )
#     651     if len(target.shape) != len(output.shape[:-1]):
# --> 652         raise ValueError(
# ...

# %%
# Out:
# Epoch 1/15
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_31/414194206.py in <cell line: 0>()
# ----> 1 history = m1.fit(
#       2     train_gen,
#       3     epochs=15,
#       4     batch_size=64
#       5 )
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/merging/base_merge.py in call(self, inputs)
#     144     def call(self, inputs):
#     145         if not isinstance(inputs, (list, tuple)):
# --> 146             raise ValueError(
# ...

# %%
m1.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_2 (Rescaling)              │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ normalization_1 (Normalization)      │ (None, 224, 224, 3)         │               7 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_3 (Rescaling)              │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ stem_conv_pad (ZeroPadding2D)        │ (None, 225, 225, 3)         │               0 │
# ...

# %%
m1.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ normalization (Normalization)        │ (None, 224, 224, 3)         │               7 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_1 (Rescaling)              │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ stem_conv_pad (ZeroPadding2D)        │ (None, 225, 225, 3)         │               0 │
# ...

# %%
round(len(efb0.layers)/5-1)
# Out:
# 47

# %%
for layer in m1.layers:
    print(layer.name)
# Out:
# rescaling
# normalization
# rescaling_1
# stem_conv_pad
# stem_conv
# stem_bn
# stem_activation
# block1a_dwconv
# block1a_bn
# block1a_activation
# block1a_se_squeeze
# block1a_se_reshape
# block1a_se_reduce
# block1a_se_expand
# block1a_se_excite
# block1a_project_conv
# block1a_project_bn
# block2a_expand_conv
# block2a_expand_bn
# block2a_expand_activation
# block2a_dwconv_pad
# block2a_dwconv
# block2a_bn
# block2a_activation
# block2a_se_squeeze
# block2a_se_reshape
# block2a_se_reduce
# block2a_se_expand
# block2a_se_excite
# block2a_project_conv
# block2a_project_bn
# block2b_expand_conv
# block2b_expand_bn
# block2b_expand_activation
# block2b_dwconv
# block2b_bn
# block2b_activation
# block2b_se_squeeze
# block2b_se_reshape
# block2b_se_reduce
# block2b_se_expand
# block2b_se_excite
# block2b_project_conv
# block2b_project_bn
# block2b_drop
# block2b_add

# %%
m2 = m1.copy()
for layer in range(round(len(efb0.layers)/5-1), round(len(efb0.layers)/5-1)+round(len(efb0.layers)/5-5)):
    m2.add(efb0.layers[layer])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_31/1983306125.py in <cell line: 0>()
# ----> 1 m2 = m1.copy()
#       2 for layer in range(round(len(efb0.layers)/5-1), round(len(efb0.layers)/5-1)+round(len(efb0.layers)/5-5)):
#       3     m2.add(efb0.layers[layer])
#
# AttributeError: 'Sequential' object has no attribute 'copy'

# %%
m2.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ normalization (Normalization)        │ (None, 224, 224, 3)         │               7 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_1 (Rescaling)              │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ stem_conv_pad (ZeroPadding2D)        │ (None, 225, 225, 3)         │               0 │
# ...

# %%
efb0.summary()
# Out:
# Model: "efficientnetb0"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling (Rescaling)     │ (None, 224, 224, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normalization             │ (None, 224, 224, 3)    │              7 │ rescaling[0][0]        │
# │ (Normalization)           │                        │                │                        │
# ...

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import EfficientNetB0
import tensorflow as tf

print("TF Version: ", tf.__version__)

def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x
